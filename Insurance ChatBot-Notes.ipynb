# %% [markdown]
# ### Prvo je potrebno da napravim virtual environment kroz comman prompt sa sledecom komandom:
# #### conda create -n chatbot python=3.5 anaconda
# ### Nakon sto se kreira virtual environment treba ga aktivirati:
# #### conda activate chatbot
# #### pip install tensorflow==1.0.0
# ![image.png](attachment:image.png)
